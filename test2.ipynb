# %%
from selenium import webdriver

# %%
import time

# %%
from bs4 import BeautifulSoup

# %%
path = '/Users/markmac/Downloads/chromedriver'

driver = webdriver.Chrome(path)
driver.get('https://www.instagram.com/')

# %%
driver.find_element_by_xpath("//button[@class = '_0mzm- sqdOP  L3NKy       ']").click()

# %%
driver.find_element_by_name('email').send_keys('ebfkdrhqnzo123@gmail.com')
driver.find_element_by_name('pass').send_keys('dkdlel12')

# %%
driver.find_element_by_xpath("//button[@class = '_42ft _4jy0 _52e0 _4jy6 _4jy1 selected _51sy']").click()

# %%
time.sleep(3)
driver.find_element_by_xpath("//button[@class = 'aOOlW  bIiDR  ']").click()

# %%
driver.find_element_by_xpath("//div[@class = 'eyXLr wUAXj ']").click()

# %%
driver.find_element_by_xpath("//input[@class = 'XTCLo x3qfX ']").send_keys('쇼미더머니777')

# %%
time.sleep(1)
driver.find_element_by_xpath("//div[@class = 'z556c']").click()

# %%
driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()

# %%
is_id = []

for i in range(10):
    time.sleep(3)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    term = soup.select('h2.BrX75 a')

    for j in term:
        is_id.append(j.text)
        
    driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()

# %%
print(is_id)
# Out:
# ['s_uhyuning', 'ji_vely_99', 'hbn_0101', 'y.jheee', 'kkikikikikikk', 'aaaaa8938', 'ramenss', 'd.ark00', 'ms.nosleep', 'onionpa_pa']

# %%
driver.close()

# %%
driver = webdriver.Chrome(path)
tag_data = []
words = []
words_list = []

for x in range(len(is_id)):
    driver.get('https://www.instagram.com/' + is_id[i])
    
    driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
    
    for i in range(10):
        time.sleep(3)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
            
        tag_data.append(soup.select('div.C4VMK > span > a'))
        
        driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
        
    for x in range(10):
        for y in range(len(tag_data[x])):
            words += tag_data[x][y]
                
    for i in words:
        if i[0] == '#':
            words_list.append(i)
                
print(words_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-88a9ec23a3b8> in <module>
# ----> 1 driver = webdriver.Chrome(path)
#       2 tag_data = []
#       3 words = []
#       4 words_list = []
#       5
#
# NameError: name 'path' is not defined

# %%
driver.close()

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
path = '/Users/markmac/Downloads/chromedriver'
driver = webdriver.Chrome(path)
driver.get('https://www.instagram.com/')

# %%
driver.find_element_by_xpath("//button[@class = '_0mzm- sqdOP  L3NKy       ']").click()

# %%
driver.find_element_by_name('email').send_keys('ebfkdrhqnzo123@gmail.com')
driver.find_element_by_name('pass').send_keys('dkdlel12')

# %%
driver.find_element_by_xpath("//button[@class = '_42ft _4jy0 _52e0 _4jy6 _4jy1 selected _51sy']").click()

# %%
time.sleep(3)
driver.find_element_by_xpath("//button[@class = 'aOOlW  bIiDR  ']").click()

# %%
driver.find_element_by_xpath("//div[@class = 'eyXLr wUAXj ']").click()
driver.find_element_by_xpath("//input[@class = 'XTCLo x3qfX ']").send_keys('쇼미더머니777')

# %%
time.sleep(1)
driver.find_element_by_xpath("//div[@class = 'z556c']").click()

# %%
time.sleep(2)
driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()

# %%
is_id = []

for i in range(10):
    time.sleep(3)
    html = driver.page_source
    dom = BeautifulSoup(html, 'html.parser')

    term = dom.select('h2.BrX75 a')

    for j in term:
        is_id.append(j.text)
        
    driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()

# %%
print(is_id)
# Out:
# ['on_the_booty', 'd.ark00', 'hurtinme', 'kidcozyboy____', 'ji_vely_99', 's_uhyuning', 'fuckingfreshfashion', 'mkitwest', 'anssojeong', 'mr_dev__777']

# %%
driver.close()
time.sleep(1)

# %%
is_id
# Out:
# ['on_the_booty',
#  'd.ark00',
#  'hurtinme',
#  'kidcozyboy____',
#  'ji_vely_99',
#  's_uhyuning',
#  'fuckingfreshfashion',
#  'mkitwest',
#  'anssojeong',
#  'mr_dev__777']

# %%
dom.select('a.HBoOv.coreSpriteRightPaginationArrow')
# Out:
# [<a class="HBoOv coreSpriteRightPaginationArrow" href="/p/1955937652592554685/" role="button" tabindex="0">다음</a>]

# %%
dom.select('a.HBoOv.coreSpriteRightPaginationArrow')[0].text
# Out:
# '다음'

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

path = '/Users/markmac/Downloads/chromedriver'

tag_data = []

for x in range(2):
    driver = webdriver.Chrome(path)
    driver.get('https://www.instagram.com/mr_dev__777')
    
    driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
    
    while True:
        try:
            time.sleep(3)
            html = driver.page_source
            dom = BeautifulSoup(html, 'html.parser')
        
            tag_data += dom.select('div.C4VMK > span > a')
        
            driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
        except:
            driver.close()
            break

# %%
tag_data
# Out:
# [<a href="/explore/tags/777/">#777</a>,
#  <a href="/explore/tags/777luckyfish/">#777luckyfish</a>,
#  <a href="/explore/tags/쇼미더머니777/">#쇼미더머니777</a>,
#  <a href="/explore/tags/777lovers/">#777lovers</a>,
#  <a href="/explore/tags/777luckyfish/">#777luckyfish</a>,
#  <a href="/explore/tags/777/">#777</a>,
#  <a href="/explore/tags/777challenge/">#777challenge</a>,
#  <a href="/explore/tags/777lovers/">#777lovers</a>,
#  <a href="/explore/tags/777/">#777</a>,
#  <a href="/explore/tags/777challenge/">#777challenge</a>,
#  <a href="/explore/tags/777/">#777</a>,
#  <a href="/explore/tags/777luckyfish/">#777luckyfish</a>,
#  <a href="/explore/tags/쇼미더머니777/">#쇼미더머니777</a>,
#  <a href="/explore/tags/777lovers/">#777lovers</a>,
#  <a href="/explore/tags/777luckyfish/">#777luckyfish</a>,
#  <a href="/explore/tags/777/">#777</a>,
#  <a href="/explore/tags/777challenge/">#777challenge</a>,
#  <a href="/explore/tags/777lovers/">#777lovers</a>,
#  <a href="/explore/tags/777/">#777</a>,
#  <a href="/explore/tags/777challenge/">#777challenge</a>]

# %%
driver = webdriver.Chrome(path)
driver.get('https://www.instagram.com/mr_dev__777')
    
driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()

for i in range(2):
    time.sleep(3)
    html = driver.page_source
    dom = BeautifulSoup(html, 'html.parser')
        
    tag_data += dom.select('div.C4VMK > span > a')
    
    print(dom.select('a.HBoOv.coreSpriteRightPaginationArrow')[0].text)
    break
    #if dom.select('a.HBoOv.coreSpriteRightPaginationArrow')[0].text != '다음':
    #    break
    #else:
    #    driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
#driver.close
# Out:
# 다음

# %%
driver = webdriver.Chrome(path)
driver.get('https://www.instagram.com/mr_dev__777')

# %%
html = driver.page_source
dom = BeautifulSoup(html, 'html.parser')

dom.select('a.HBoOv.coreSpriteRightPaginationArrow')[0]
# Out:
# <a class="HBoOv coreSpriteRightPaginationArrow" href="/p/1954942357474374780/" role="button" tabindex="0">다음</a>

# %%
tag_data = []
ss = []

for x in range(len(is_id)):
    driver = webdriver.Chrome(path)
    driver.get('https://www.instagram.com/' + is_id[x])
    
    driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
    
    for y in range(5):
        time.sleep(3)
        html = driver.page_source
        dom = BeautifulSoup(html, 'html.parser')
        
        tag_data += dom.select('div.C4VMK > span > a')
            
        if dom in dom.select('div.D1AKJ > a.HBoOv.coreSpriteRightPaginationArrow'):
            driver.find_element_by_xpath("//a[@class = 'HBoOv.coreSpriteRightPaginationArrow']").click()
        else:
            break
        
        #if dom.select('div.D1AKJ a') in dom.select('a.HBoOv coreSpriteRightPaginationArrow'):
        #    driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
    driver.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-87-8e3bb0ef9228> in <module>
#       6     driver.get('https://www.instagram.com/' + is_id[x])
#       7
# ----> 8     driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
#       9
#      10     for y in range(5):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615355 (d5698f682d8b2742017df6c81e0bd8e6a3063189),platform=Mac OS X 10.13.6 x86_64)

# %%
driver.find_element_by_css_selector(".HBoOv.coreSpriteRightPaginationArrow")
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-116-fe043d58c90b> in <module>
# ----> 1 driver.find_element_by_css_selector(".HBoOv.coreSpriteRightPaginationArrow")
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615355 (d5698f682d8b2742017df6c81e0bd8e6a3063189),platform=Mac OS X 10.13.6 x86_64)

# %%
driver = webdriver.Chrome(path)
driver.get('https://www.instagram.com/' + is_id[x])
    
driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()

# %%
html = driver.page_source
dom = BeautifulSoup(html, 'html.parser')

if dom.select('div.D1AKJ') in dom.select('a.HBoOv.coreSpriteRightPaginationArrow'):
    print('ss')

# %%
a = dom.select('div.D1AKJ')

# %%
for i, line in enumerate(a):
    driver.get(line['role'])
    time.sleep
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-35d2fef5d318> in <module>
#       1 for i, line in enumerate(a):
# ----> 2     driver.get(line['role'])
#       3     time.sleep
#
# /anaconda3/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#    1069         """tag[key] returns the value of the 'key' attribute for the tag,
#    1070         and throws an exception if it's not there."""
# -> 1071         return self.attrs[key]
#    1072
#    1073     def __iter__(self):
#
# KeyError: 'role'

# %%
driver.find_element_by_xpath('div.D1AKJ a')
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-85-37f026fd9162> in <module>
# ----> 1 driver.find_element_by_xpath('div.D1AKJ a')
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSelectorException: Message: invalid selector: Unable to locate an element with the xpath expression div.D1AKJ a because of the following error:
# SyntaxError: Failed to execute 'evaluate' on 'Document': The string 'div.D1AKJ a' is not a valid XPath expression.
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615355 (d5698f682d8b2742017df6c81e0bd8e6a3063189),platform=Mac OS X 10.13.6 x86_64)

# %%
if dom.select('div.D1AKJ a') not in 'HBoOv coreSpriteRightPaginationArrow':
    continue
# Out:
#   File "cell_name", line 5
# SyntaxError: 'continue' not properly in loop

# %%
dom.select('a.HBoOv.coreSpriteRightPaginationArrow')
# Out:
# [<a class="HBoOv coreSpriteRightPaginationArrow" href="/p/1950897561619859760/" role="button" tabindex="0">다음</a>]

# %%
for q in soup.select('div.D1AKJ a'):
    ss.append(q.text)
    if len(ss) > 1:
        if ss[1] in '다음':
            driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
        else:
            break

# %%
print(tag_data)
# Out:
# [<a href="/explore/tags/단발/">#단발</a>, <a href="/explore/tags/셀피/">#셀피</a>, <a href="/explore/tags/패션/">#패션</a>, <a href="/explore/tags/맞팔/">#맞팔</a>, <a href="/explore/tags/무쌍/">#무쌍</a>, <a href="/explore/tags/팔로우/">#팔로우</a>, <a href="/explore/tags/셀스타그램/">#셀스타그램</a>, <a href="/explore/tags/선팔/">#선팔</a>, <a href="/explore/tags/까페/">#까페</a>, <a href="/explore/tags/소통/">#소통</a>, <a href="/explore/tags/인스타/">#인스타</a>, <a href="/explore/tags/전주/">#전주</a>, <a href="/explore/tags/followforfollow/">#followforfollow</a>, <a href="/explore/tags/instagood/">#instagood</a>, <a href="/explore/tags/거울샷/">#거울샷</a>, <a href="/explore/tags/19/">#19</a>, <a href="/explore/tags/20/">#20</a>, <a href="/explore/tags/좋아요반사/">#좋아요반사</a>, <a href="/explore/tags/instalike/">#instalike</a>, <a href="/explore/tags/like/">#like</a>, <a href="/explore/tags/follow/">#follow</a>, <a href="/explore/tags/instadaily/">#instadaily</a>, <a href="/explore/tags/fff/">#fff</a>, <a href="/explore/tags/f4f/">#f4f</a>, <a href="/explore/tags/lfl/">#lfl</a>, <a href="/explore/tags/l4l/">#l4l</a>, <a href="/explore/tags/like4like/">#like4like</a>, <a href="/explore/tags/follow4follow/">#follow4follow</a>, <a href="/explore/tags/selca/">#selca</a>, <a href="/explore/tags/selfie/">#selfie</a>, <a href="/explore/tags/단발/">#단발</a>, <a href="/explore/tags/셀피/">#셀피</a>, <a href="/explore/tags/패션/">#패션</a>, <a href="/explore/tags/맞팔/">#맞팔</a>, <a href="/explore/tags/무쌍/">#무쌍</a>, <a href="/explore/tags/팔로우/">#팔로우</a>, <a href="/explore/tags/셀스타그램/">#셀스타그램</a>, <a href="/explore/tags/선팔/">#선팔</a>, <a href="/explore/tags/까페/">#까페</a>, <a href="/explore/tags/소통/">#소통</a>, <a href="/explore/tags/인스타/">#인스타</a>, <a href="/explore/tags/전주/">#전주</a>, <a href="/explore/tags/followforfollow/">#followforfollow</a>, <a href="/explore/tags/instagood/">#instagood</a>, <a href="/explore/tags/거울샷/">#거울샷</a>, <a href="/explore/tags/19/">#19</a>, <a href="/explore/tags/20/">#20</a>, <a href="/explore/tags/좋아요반사/">#좋아요반사</a>, <a href="/explore/tags/instalike/">#instalike</a>, <a href="/explore/tags/like/">#like</a>, <a href="/explore/tags/follow/">#follow</a>, <a href="/explore/tags/instadaily/">#instadaily</a>, <a href="/explore/tags/fff/">#fff</a>, <a href="/explore/tags/f4f/">#f4f</a>, <a href="/explore/tags/lfl/">#lfl</a>, <a href="/explore/tags/l4l/">#l4l</a>, <a href="/explore/tags/like4like/">#like4like</a>, <a href="/explore/tags/follow4follow/">#follow4follow</a>, <a href="/explore/tags/selca/">#selca</a>, <a href="/explore/tags/selfie/">#selfie</a>, <a class="notranslate" href="/dabeendl/">@dabeendl</a>, <a class="notranslate" href="/ayeong0301/">@ayeong0301</a>, <a class="notranslate" href="/on_the_booty/">@on_the_booty</a>, <a class="notranslate" href="/so_os98k/">@so_os98k</a>, <a class="notranslate" href="/heabiny/">@heabiny</a>, <a class="notranslate" href="/thetruthinyourheart/">@thetruthinyourheart</a>, <a class="notranslate" href="/sexy_pop_girl/">@sexy_pop_girl</a>, <a class="notranslate" href="/jijiji0231/">@jijiji0231</a>, <a href="/explore/tags/단발/">#단발</a>, <a href="/explore/tags/셀피/">#셀피</a>, <a href="/explore/tags/패션/">#패션</a>, <a href="/explore/tags/맞팔/">#맞팔</a>, <a href="/explore/tags/무쌍/">#무쌍</a>, <a href="/explore/tags/팔로우/">#팔로우</a>, <a href="/explore/tags/셀스타그램/">#셀스타그램</a>, <a href="/explore/tags/선팔/">#선팔</a>, <a href="/explore/tags/까페/">#까페</a>, <a href="/explore/tags/소통/">#소통</a>, <a href="/explore/tags/인스타/">#인스타</a>, <a href="/explore/tags/전주/">#전주</a>, <a href="/explore/tags/followforfollow/">#followforfollow</a>, <a href="/explore/tags/instagood/">#instagood</a>, <a href="/explore/tags/거울샷/">#거울샷</a>, <a href="/explore/tags/19/">#19</a>, <a href="/explore/tags/20/">#20</a>, <a href="/explore/tags/좋아요반사/">#좋아요반사</a>, <a href="/explore/tags/instalike/">#instalike</a>, <a href="/explore/tags/like/">#like</a>, <a href="/explore/tags/follow/">#follow</a>, <a href="/explore/tags/instadaily/">#instadaily</a>, <a href="/explore/tags/fff/">#fff</a>, <a href="/explor ...

# %%
words = []

for z in tag_data:
    words.append(z.text)

# %%
words
# Out:
# ['#단발',
#  '#셀피',
#  '#패션',
#  '#맞팔',
#  '#무쌍',
#  '#팔로우',
#  '#셀스타그램',
#  '#선팔',
#  '#까페',
#  '#소통',
#  '#인스타',
#  '#전주',
#  '#followforfollow',
#  '#instagood',
#  '#거울샷',
#  '#19',
#  '#20',
#  '#좋아요반사',
#  '#instalike',
#  '#like',
#  '#follow',
#  '#instadaily',
#  '#fff',
#  '#f4f',
#  '#lfl',
#  '#l4l',
#  '#like4like',
#  '#follow4follow',
#  '#selca',
#  '#selfie',
#  '#단발',
#  '#셀피',
#  '#패션',
#  '#맞팔',
#  '#무쌍',
#  '#팔로우',
#  '#셀스타그램',
#  '#선팔',
#  '#까페',
#  '#소통',
#  '#인스타',
#  '#전주',
#  '#followforfollow',
#  '#instagood',
#  '#거울샷',
#  '#19',
#  '#20',
#  '#좋아요반사',
#  '#instalike',
#  '#like',
#  '#follow',
#  '#instadaily',
#  '#fff',
#  '#f4f',
#  '#lfl',
#  '#l4l',
#  '#like4like',
#  '#follow4follow',
#  '#selca',
#  '#selfie',
#  '@dabeendl',
#  '@ayeong0301',
#  '@on_the_booty',
#  '@so_os98k',
#  '@heabiny',
#  '@thetruthinyourheart',
#  '@sexy_pop_girl',
#  '@jijiji0231',
#  '#단발',
#  '#셀피',
#  '#패션',
#  '#맞팔',
#  '#무쌍',
#  '#팔로우',
#  '#셀스타그램',
#  '#선팔',
#  '#까페',
#  '#소통',
#  '#인스타',
#  '#전주',
#  '#followforfollow',
#  '#instagood',
#  '#거울샷',
#  '#19',
#  '#20',
#  '#좋아요반사',
#  '#instalike',
#  '#like',
#  '#follow',
#  '#instadaily',
#  '#fff',
#  '#f4f',
#  '#lfl',
#  '#l4l',
#  '#like4like',
#  '#follow4follow',
#  '#selca',
#  '#selfie',
#  '@lluyyull',
#  '@marimo_hime',
#  '@on_the_booty',
#  '@s_miin_',
#  '@kaiiqz',
#  '@haemunimu',
#  '@anju_why_sal_a',
#  '#디아크',
#  '#디아크',
#  '@sempak_hanbin.wangi',
#  '#디아크',
#  '#디아크',
#  '#d',
#  '#dark',
#  '#d_ark',
#  '#showmethemoney',
#  '#showmethemoney7',
#  '#showmethemoney777',
#  '#smtm7',
#  '#smtm',
#  '#smtm777',
#  '#디아크',
#  '@dmofxxkinark',
#  '#쇼미더머니777',
#  '#쇼미더머니',
#  '#쇼미더머니7',
#  '@sekarwulandari__',
#  '@mar.celinoo',
#  '#카페',
#  '#카페언더나인',
#  '#커피',
#  '#딸기',
#  '#케이크',
#  '#언더나인',
#  '#cake',
#  '#coffee',
#  '#cafe',
#  '#홍춘천닭갈비',
#  '#홍춘천치즈닭갈비',
#  '#닭갈비',
#  '#치즈',
#  '#점심',
#  '#황성동맛집',
#  '#경주맛집',
#  '@promeneur6747',
#  '@jung_a_6878',
#  '#달콤한나의도시',
#  '#오늘책방을닫았습니다',
#  '#책방',
#  '#정이현',
#  '#소설',
#  '#책추천',
#  '#문학과지성사',
#  '#송은정',
#  '#에세이',
#  '#효형출판',
#  '#책',
#  '#독서',
#  '#book',
#  '@mindoooong',
#  '#해루질',
#  '#문어',
#  '#낙지',
#  '#겨울바다',
#  '#밤바다',
#  '#바다',
#  '@promeneur6747',
#  '#겨울나그네',
#  '#빌헬름뮐러',
#  '#슈베르트',
#  '#민음사',
#  '#시',
#  '#나는둔감하게살기로했다',
#  '#둔감력',
#  '#와타나베준이치',
#  '#다산초당',
#  '#책',
#  '#독서',
#  '#book',
#  '@promeneur6747',
#  '@hurtinme',
#  '@promeneur6747']

# %%
words_list = []

for a in words:
    if a[0] == '#':
        words_list.append(a)

# %%
words_list
# Out:
# ['#단발',
#  '#셀피',
#  '#패션',
#  '#맞팔',
#  '#무쌍',
#  '#팔로우',
#  '#셀스타그램',
#  '#선팔',
#  '#까페',
#  '#소통',
#  '#인스타',
#  '#전주',
#  '#followforfollow',
#  '#instagood',
#  '#거울샷',
#  '#19',
#  '#20',
#  '#좋아요반사',
#  '#instalike',
#  '#like',
#  '#follow',
#  '#instadaily',
#  '#fff',
#  '#f4f',
#  '#lfl',
#  '#l4l',
#  '#like4like',
#  '#follow4follow',
#  '#selca',
#  '#selfie',
#  '#단발',
#  '#셀피',
#  '#패션',
#  '#맞팔',
#  '#무쌍',
#  '#팔로우',
#  '#셀스타그램',
#  '#선팔',
#  '#까페',
#  '#소통',
#  '#인스타',
#  '#전주',
#  '#followforfollow',
#  '#instagood',
#  '#거울샷',
#  '#19',
#  '#20',
#  '#좋아요반사',
#  '#instalike',
#  '#like',
#  '#follow',
#  '#instadaily',
#  '#fff',
#  '#f4f',
#  '#lfl',
#  '#l4l',
#  '#like4like',
#  '#follow4follow',
#  '#selca',
#  '#selfie',
#  '#단발',
#  '#셀피',
#  '#패션',
#  '#맞팔',
#  '#무쌍',
#  '#팔로우',
#  '#셀스타그램',
#  '#선팔',
#  '#까페',
#  '#소통',
#  '#인스타',
#  '#전주',
#  '#followforfollow',
#  '#instagood',
#  '#거울샷',
#  '#19',
#  '#20',
#  '#좋아요반사',
#  '#instalike',
#  '#like',
#  '#follow',
#  '#instadaily',
#  '#fff',
#  '#f4f',
#  '#lfl',
#  '#l4l',
#  '#like4like',
#  '#follow4follow',
#  '#selca',
#  '#selfie',
#  '#디아크',
#  '#디아크',
#  '#디아크',
#  '#디아크',
#  '#d',
#  '#dark',
#  '#d_ark',
#  '#showmethemoney',
#  '#showmethemoney7',
#  '#showmethemoney777',
#  '#smtm7',
#  '#smtm',
#  '#smtm777',
#  '#디아크',
#  '#쇼미더머니777',
#  '#쇼미더머니',
#  '#쇼미더머니7',
#  '#카페',
#  '#카페언더나인',
#  '#커피',
#  '#딸기',
#  '#케이크',
#  '#언더나인',
#  '#cake',
#  '#coffee',
#  '#cafe',
#  '#홍춘천닭갈비',
#  '#홍춘천치즈닭갈비',
#  '#닭갈비',
#  '#치즈',
#  '#점심',
#  '#황성동맛집',
#  '#경주맛집',
#  '#달콤한나의도시',
#  '#오늘책방을닫았습니다',
#  '#책방',
#  '#정이현',
#  '#소설',
#  '#책추천',
#  '#문학과지성사',
#  '#송은정',
#  '#에세이',
#  '#효형출판',
#  '#책',
#  '#독서',
#  '#book',
#  '#해루질',
#  '#문어',
#  '#낙지',
#  '#겨울바다',
#  '#밤바다',
#  '#바다',
#  '#겨울나그네',
#  '#빌헬름뮐러',
#  '#슈베르트',
#  '#민음사',
#  '#시',
#  '#나는둔감하게살기로했다',
#  '#둔감력',
#  '#와타나베준이치',
#  '#다산초당',
#  '#책',
#  '#독서',
#  '#book']

# %%
from wordcloud import WordCloud

# %%
f = open('/Users/markmac/Downloads/word_data.txt', 'w')
for i in range(len(words_list)):
    f.write(words_list[i] + "\n")
f.close()
        
text = open('/Users/markmac/Downloads/word_data.txt').read()
        
wordcloud = WordCloud(max_font_size = 30, font_path = '/Users/markmac/Fonts/NanumSquareBold.ttf', background_color = 'white').generate(text)

# %%
wordcloud.words_
# Out:
# {'디아크': 1.0,
#  '단발': 0.6,
#  '셀피': 0.6,
#  '패션': 0.6,
#  '맞팔': 0.6,
#  '무쌍': 0.6,
#  '팔로우': 0.6,
#  '셀스타그램': 0.6,
#  '선팔': 0.6,
#  '까페': 0.6,
#  '소통': 0.6,
#  '인스타': 0.6,
#  '전주': 0.6,
#  'followforfollow': 0.6,
#  'instagood': 0.6,
#  '거울샷': 0.6,
#  '좋아요반사': 0.6,
#  'instalike': 0.6,
#  'follow': 0.6,
#  'instadaily': 0.6,
#  'fff': 0.6,
#  'f4f': 0.6,
#  'lfl': 0.6,
#  'l4l': 0.6,
#  'like4like': 0.6,
#  'follow4follow': 0.6,
#  'selca': 0.6,
#  'selfie': 0.6,
#  '독서': 0.4,
#  'book': 0.4,
#  'dark': 0.2,
#  'd_ark': 0.2,
#  'showmethemoney': 0.2,
#  'showmethemoney7': 0.2,
#  'showmethemoney777': 0.2,
#  'smtm7': 0.2,
#  'smtm': 0.2,
#  'smtm777': 0.2,
#  '쇼미더머니777': 0.2,
#  '쇼미더머니': 0.2,
#  '쇼미더머니7': 0.2,
#  '카페': 0.2,
#  '카페언더나인': 0.2,
#  '커피': 0.2,
#  '딸기': 0.2,
#  '케이크': 0.2,
#  '언더나인': 0.2,
#  'cake': 0.2,
#  'coffee': 0.2,
#  'cafe': 0.2,
#  '홍춘천닭갈비': 0.2,
#  '홍춘천치즈닭갈비': 0.2,
#  '닭갈비': 0.2,
#  '치즈': 0.2,
#  '점심': 0.2,
#  '황성동맛집': 0.2,
#  '경주맛집': 0.2,
#  '달콤한나의도시': 0.2,
#  '오늘책방을닫았습니다': 0.2,
#  '책방': 0.2,
#  '정이현': 0.2,
#  '소설': 0.2,
#  '책추천': 0.2,
#  '문학과지성사': 0.2,
#  '송은정': 0.2,
#  '에세이': 0.2,
#  '효형출판': 0.2,
#  '해루질': 0.2,
#  '문어': 0.2,
#  '낙지': 0.2,
#  '겨울바다': 0.2,
#  '밤바다': 0.2,
#  '바다': 0.2,
#  '겨울나그네': 0.2,
#  '빌헬름뮐러': 0.2,
#  '슈베르트': 0.2,
#  '민음사': 0.2,
#  '나는둔감하게살기로했다': 0.2,
#  '둔감력': 0.2,
#  '와타나베준이치': 0.2,
#  '다산초당': 0.2}

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (40, 40))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off') # x, y축 scale(숫자) 없애기.
plt.show()
plt.savefig('words_hiphop.png') # 이미지 파일 저장

# %%
tag_data = []
words = []
words_list = []
hashtags = []
ss = []

for x in range(len(is_id)):
    driver = webdriver.Chrome(path)
    driver.get('https://www.instagram.com/' + is_id[x])
    
    driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
    
    for y in range(10):
        time.sleep(3)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
            
        tag_data += soup.select('div.C4VMK > span > a')
        
        for q in soup.select('div.D1AKJ a'):
            ss.append(q.text)
            if len(ss) > 1:
                if ss[1] in '다음':
                    driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
                else:
                    break
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-128-196ac8d6be8e> in <module>
#       7 for x in range(len(is_id)):
#       8     driver = webdriver.Chrome(path)
# ----> 9     driver.get('https://www.instagram.com/' + is_id[x])
#      10
#      11     driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from disconnected: received Inspector.detached event
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615355 (d5698f682d8b2742017df6c81e0bd8e6a3063189),platform=Mac OS X 10.13.6 x86_64)

# %%
from selenium.webdriver.common.keys import Keys

url = 'https://www.google.com/search?q=%ED%99%8D%EC%A7%84%EC%98%81&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjhh8Olu9rdAhXLa7wKHa_9CBYQ_AUICigB&biw=431&bih=915'
driver.get(url)
dom = BeautifulSoup(driver.page_source, 'lxml')

imgWrap = driver.find_element_by_tag_name('body')
while True:
    imgWrap.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
    dom = BeautifulSoup(driver.page_source, 'lxml')
    
    if dom.select('#smc')[0]['style'] == 'display:none':
        continue
    else:
        driver.find_element_by_id("smb").click()
        break
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-130-783d1c205879> in <module>
#       2
#       3 url = 'https://www.google.com/search?q=%ED%99%8D%EC%A7%84%EC%98%81&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjhh8Olu9rdAhXLa7wKHa_9CBYQ_AUICigB&biw=431&bih=915'
# ----> 4 driver.get(url)
#       5 dom = BeautifulSoup(driver.page_source, 'lxml')
#       6
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615355 (d5698f682d8b2742017df6c81e0bd8e6a3063189),platform=Mac OS X 10.13.6 x86_64)
