# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import time
# %matplotlib inline

path = '/Users/markmac/Downloads/chromedriver'
driver = webdriver.Chrome(path)
driver.get('https://www.instagram.com/')

driver.find_element_by_xpath("//button[@class = '_0mzm- sqdOP  L3NKy       ']").click()

driver.find_element_by_name('email').send_keys('ebfkdrhqnzo123@gmail.com')
driver.find_element_by_name('pass').send_keys('dkdlel12')

driver.find_element_by_xpath("//button[@class = '_42ft _4jy0 _52e0 _4jy6 _4jy1 selected _51sy']").click()

time.sleep(3)
driver.find_element_by_xpath("//button[@class = 'aOOlW  bIiDR  ']").click()

driver.find_element_by_xpath("//div[@class = 'eyXLr wUAXj ']").click()
driver.find_element_by_xpath("//input[@class = 'XTCLo x3qfX ']").send_keys('쇼미더머니777')
time.sleep(1)
driver.find_element_by_xpath("//div[@class = 'z556c']").click()

time.sleep(2)
driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()

is_id = []

for i in range(3):
    time.sleep(3)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    term = soup.select('h2.BrX75 a')

    for j in term:
        is_id.append(j.text)
        
    driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
    
driver.close()

time.sleep(1)

tag_data = []
words = []
words_list = []
ss = []

for x in range(len(is_id)):
    driver = webdriver.Chrome(path)
    driver.get('https://www.instagram.com/' + is_id[x])
    
    driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
    
    #for y in range(5):
    #    time.sleep(3)
    #    html = driver.page_source
    #    soup = BeautifulSoup(html, 'html.parser')
            
    #    tag_data += soup.select('div.C4VMK > span > a')
        
    #    driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
        
        
    while True:
        try:
            time.sleep(3)
            html = driver.page_source
            dom = BeautifulSoup(html, 'html.parser')
        
            tag_data += dom.select('div.C4VMK > span > a')
        
            driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
        except:
            driver.close()
            break 
    
    time.sleep(1)

for z in tag_data:
    words.append(z.text)
    
for a in words:
    if a[0] == '#':
        words_list.append(a)
        
print(words_list)
    
f = open('/Users/markmac/Downloads/is_tagsdata.txt', 'w')
for i in range(len(words_list)):
    f.write(words_list[i] + "\n")
f.close()
        
text = open('/Users/markmac/Downloads/is_tagsdata.txt').read()
        
wordcloud = WordCloud(max_font_size = 30, font_path = '/Users/markmac/Fonts/NanumSquareBold.ttf', background_color = 'white').generate(text)

plt.figure(figsize = (40, 40))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off') # x, y축 scale(숫자) 없애기.
plt.show()
plt.savefig('test')
# Out:
# ['#brocurly', '#dnow', '#partichild', '#vegetablegang', '#vegetablechallenge', '#고등래퍼3', '#고등래퍼3지원', '#훼이크다이것들아', '#최은서', '#undercloud', '#오픈마이크스웨거', '#openmicswg', '#지원', '#최은서', '#쇼미더머니7', '#지원', '#영상', '#쇼미', '#쇼미7', '#트리플세븐', '#777', '#TD', '#squad', '#출격', '#showmethemoney777', '#쇼미더머니777', '#쇼미더머니777지원', '#쇼미777지원', '#happynewyear', '#openmicswg', '#오픈마이크스웨거', '#VAT', '#SINCE', '#Repost', '#alldayout', '#goldbars', '#beaplayer', '#Repost', '#QM', '#Cwhy', '#Odayosa', '#hariboi', '#curvesworth', '#was', '#remixtape', '#wasfromus', '#쇼미더머니777지원', '#쇼미더머니777', '#무반주', '#쇼미더머니777지원', '#쇼미777지원', '#슈퍼루키', '#챌린지', '#슈루챌', '#11', '#합정', '#프리즘홀', '#공연', '#live', '#hiphop', '#rap', '#music', '#daily', '#blacksoul', '#good', '#playground', '#Repost', '#올더비트', '#엔도킴', '#영키드', '#SINCE', '#져지제이', '#372', '#온리', '#오데이오사', '#스콸로웨이브', '#cardib', '#migos', '#drip', '#cover', '#aomg', '#illionaire', '#h1ghrmusic', '#hiphop', '#rap', '#music', '#good', '#daily', '#art', '#instagram', '#since', '#flf', '#l4l', '#video', '#음스타그램', '#action', '#dprlive', '#❣', '#어글리정션', '#올더비트', '#tonight', '#jazz', '#공연', '#nice', '#place', '#since', '#Repost', '#올더비트배틀', '#1', '#코잇', '#올더비트', '#올더비트배틀본선', '#코잇', '#COIT', '#crknfilm', '#노트북', '#삼성노트북', '#뮤비', '#뮤직비디오', '#음악', '#음악스타그램', '#힙합', '#뮤직스타그램', '#공연', '#패션', '#스트릿패션', '#일상', '#daily', '#dailymusic', '#f4f', '#올더비트', '#올더비트배틀_래퍼', '#rap', '#hiphop', '#beat', '#music', '#good', '#seoul', '#all', '#illust', '#purple', '#daily', '#artwork', '#seoul', '#good', '#ootd', '#fashion', '#l4l', '#snp', '#show', '#cypher', '#mtc', '#movethecrowd', '#hiphop', '#music', '#video', '#rap', '#good', '#lfl', '#f4f', '#daily', '#서울', '#since', '#caid', '#clloud', '#wanderoo', '#crakenfilm', '#ThatSIGNS', '#댓사인즈지원', '#보통래퍼시즌3', '#마운틴듀', '#필라', '#fila', '#명동', '#hiphop', '#우디고차일드', '#크루셜스타', '#도넛맨', '#공연', '#seoul', '#since', '#보통래퍼시즌3', '#마운틴듀', '#휠라', '#fila', '#dothedew', '#셀스타그램', '#셀피', '#selfie', '#서울', '#daily', '#l4l', '#f4f', '#music', '#hiphop', '#rap', '#jayz', '#bluemagic', '#good', '#맥도날드', '#고등래퍼3', '#고랩3', '#고등래퍼지원', '#고등래퍼3지원', '#고랩3지원', '#highschoolrapper', '#우희원', '#레게', '#힙합', '#레게힙합', '#18', '#01', '#랩', '#HipHop', '#rap', '#Reggae', '#공유', '#공유해줘요', '#좋아요', '#좋아요', '#청주', '#충북', '#충청북도', '#가경동', '#쇼미더머니777지원', '#쇼미지원777', '#쇼미더머니7', '#쇼미더머니지원', '#쇼미지원7', '#레게힙합', '#레게', '#힙합', '#18살', '#01', '#청주', '#랩', '#HipHop', '#Rap', '#아파', '#병원', '#링겔', '#한결편해', '#하나병원', '#병문안', '#와줘', '#고등래퍼2', '#자퇴생', '#레게', '#레게힙합', '#18', '#우희원', '#파이팅']

# %%
path = '/Users/markmac/Downloads/chromedriver'
driver = webdriver.Chrome(path)
driver.get('https://www.instagram.com/kkikikikikikk/')

# %%
driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-131-795c5c46b7e1> in <module>
# ----> 1 driver.find_element_by_xpath("//div[@class = '_9AhH0']").click()
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615355 (d5698f682d8b2742017df6c81e0bd8e6a3063189),platform=Mac OS X 10.13.6 x86_64)

# %%
if soup.select('div.C4VMK > span > a')['class'] == 'HBoOv coreSpriteRightPaginationArrow':
    driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
else:
    driver.find_element_by_xpath("//button[@class = 'ckWGn']").click()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-fb30960d0f79> in <module>
# ----> 1 if soup.select('div.C4VMK > span > a')['class'] == 'HBoOv coreSpriteRightPaginationArrow':
#       2     driver.find_element_by_xpath("//a[@class = 'HBoOv coreSpriteRightPaginationArrow']").click()
#       3 else:
#       4     driver.find_element_by_xpath("//button[@class = 'ckWGn']").click()
#
# TypeError: list indices must be integers or slices, not str

# %%
print(soup.select('div.D1AKJ a'))
# Out:
# [<a class="HBoOv coreSpriteRightPaginationArrow" href="/p/1950243427421963495/" role="button" tabindex="0">다음</a>]

# %%
for i in soup.select('div.D1AKJ a'):
    a = i.text

# %%
a
# Out:
# '다음'

# %%
if soup.select('div.D1AKJ a') 
    print("ss")

# %%
soup.select('div.D1AKJ a')
# Out:
#   File "<ipython-input-79-afad17d159a2>", line 1
#     soup.select('div.D1AKJ a').class
#                                    ^
# SyntaxError: invalid syntax

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
driver.find_element_by_class_name('HBoOv coreSpriteRightPaginationArrow')
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-97-6e475f26e926> in <module>
# ----> 1 driver.find_element_by_class_name('HBoOv coreSpriteRightPaginationArrow')
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSelectorException: Message: invalid selector: Compound class names not permitted
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615355 (d5698f682d8b2742017df6c81e0bd8e6a3063189),platform=Mac OS X 10.13.6 x86_64)

# %%
ss = []

for i in soup.select('div.D1AKJ a'):
    ss.append(i.text)
    if len(ss) > 1:
        if ss[1] not in '다음':
            print('ss')
        else:
            print('aa')
    else:
        print('xx')
# Out:
# xx

# %%
type(ss)
# Out:
# list

# %%
print(ss)
# Out:
# ['다음']

# %%
qq = ['이전', '다음']

if len(qq) > 1:
    if qq[1] in '다음':
        print('click')
    else:
        print('break')
# Out:
# click
